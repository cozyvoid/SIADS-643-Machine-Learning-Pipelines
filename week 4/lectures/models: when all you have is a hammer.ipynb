# %% [markdown]
# # Models: When all you have is a Hammer
#
# ---

# %% [markdown]
# ### Reasons not to build a model
#
# - Data
# - Ethics
# - Someone else already has

# %% [markdown]
# ### Not all data fits
#
# - Not all data fits in a pipeline or a model
# - Sometimes, the best course of action is to do nothing, or find a different way to get to business results.

# %% [markdown]
# ### Ethics
#
# - Just because you can, does not mean you should

# %% [markdown]
# ### Lots of models are out there
#
# - Can you use one rather than build one?
