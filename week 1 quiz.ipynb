# %% [markdown]
# # Week 1 Quiz
#
# ---

# %% [markdown]
# ### 1. Which of the following are things that an IDE can do?
#
# - [ ] Automate building models without any code.
# - [x] Can be extended with plugins.
# - [x] Show the parameters that functions take.
# - [x] Rude code with a single button.
# - [x] Help with indentation/code formatting.
# - [ ] Make assumptions about how you will use your code.

# %% [markdown]
# ### 2. Why might you not use a notebook to build machine learning pipelines?
#
# - [x] It is best to build your pipeline in a similar manner that you will run it in. Most servers don't run browsers.
# - [ ] Notebooks can't be used to clean large amounts of data as the kernal will crash.

# %% [markdown]
# Notebooks are excellent for exploration and experimentation, but production pipelines are usually executed as scripts or applications on servers.
