# %% [markdown]
# # Week 2 Readings Quiz
#
# ---

# %% [markdown]
# ### 1. Which of the following statements accurately captures a concern raised in the passage about machine learning systems and their data?
#
# - [ ] Machine learning systems always require up-to-date tables for optimal performance.
# - [ ] Silent failures are a common problem in all types of systems.
# - [x] Out-of-date tables can cause machine learning systems to adjust and still perform reasonably well, but refreshing the data can significantly boost performance.
# - [ ] One should only manually inspect the data to avoid silent failures in machine learning systems.

# %% [markdown]
# ### 2. Which statement best describes the guidance on using features in data?
#
# - [ ] It is always better to use complex features with limited data.
# - [ ] Documents' identifiers and canonicalized queries offer high generalization and are the primary sources for feature extraction.
# - [x] With large datasets, it's easier to learn many simple features rather than a few complex ones, and it's okay if each feature applies to a small fraction of data as long as overall coverage is above 90%.
# - [ ] Regularization is not needed when dealing with large datasets.

# %% [markdown]
# ### 3. Which of the following can indicate poor data quality?
#
# - [x] Missing data points
# - [x] Imprecise data
# - [x] Corrupted data
# - [ ] Co-joined featues

# %% [markdown]
# ### 4. When working with a dataset to predict user clicks on an ad, what is commonly present in the dataset?
#
# - [ ] Current market trends
# - [x] A historical log of all clicks for a specific time period
# - [ ] User preferences for ad colors
# - [ ] Website traffic patterns
